# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk

# %%
# reads the data set from the file
data = pd.read_excel("Residential-Building-Data-Set.xlsx", sheet_name=0)

# %%
data
# Out:
#     PROJECT DATES (PERSIAN CALENDAR)     Unnamed: 1       Unnamed: 2  \
# 0                         START YEAR  START QUARTER  COMPLETION YEAR
# 1                                 81              1               85
# 2                                 84              1               89
# 3                                 78              1               81
# 4                                 72              2               73
# ..                               ...            ...              ...
# 368                               83              4               86
# 369                               81              2               82
# 370                               84              4               86
# 371                               82              3               84
# 372                               80              1               81
#
#              Unnamed: 3 PROJECT PHYSICAL AND FINANCIAL VARIABLES Unnamed: 5  \
# ...

# %%
data.columns
# Out:
# Index(['PROJECT DATES (PERSIAN CALENDAR)', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'PROJECT PHYSICAL AND FINANCIAL VARIABLES', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 99', 'Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102',
#        'Unnamed: 103', 'Unnamed: 104', 'Unnamed: 105', 'Unnamed: 106',
#        'OUTPUTS', 'Unnamed: 108'],
#       dtype='object', length=109)

# %%
data.head()
# Out:
#   PROJECT DATES (PERSIAN CALENDAR)     Unnamed: 1       Unnamed: 2  \
# 0                       START YEAR  START QUARTER  COMPLETION YEAR
# 1                               81              1               85
# 2                               84              1               89
# 3                               78              1               81
# 4                               72              2               73
#
#            Unnamed: 3 PROJECT PHYSICAL AND FINANCIAL VARIABLES Unnamed: 5  \
# 0  COMPLETION QUARTER                                      V-1        V-2
# 1                   1                                        1       3150
# 2                   4                                        1       7600
# 3                   4                                        1       4800
# 4                   2                                        1        685
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 99 Unnamed: 100  \
# ...

# %%
data.shape
# Out:
# (373, 109)

# %%
#naming of columns
data['Unnamed: 1']
# Out:
# 0      START QUARTER
# 1                  1
# 2                  1
# 3                  1
# 4                  2
#            ...
# 368                4
# 369                2
# 370                4
# 371                3
# 372                1
# Name: Unnamed: 1, Length: 373, dtype: object

# %%
#renaming the columns by deleting 1st row and making 2nd row as the header

new_header = data.iloc[0] #grab the first row for the header
data = data[1:] #take the data less the header row
data.columns = new_header #set the header row as the df header

# %%
#dataset with column names changed
data
# Out:
# 0   START YEAR START QUARTER COMPLETION YEAR COMPLETION QUARTER V-1   V-2  \
# 1           81             1              85                  1   1  3150
# 2           84             1              89                  4   1  7600
# 3           78             1              81                  4   1  4800
# 4           72             2              73                  2   1   685
# 5           87             1              90                  2   1  3000
# ..         ...           ...             ...                ...  ..   ...
# 368         83             4              86                  1  20  1350
# 369         81             2              82                  4  20   600
# 370         84             4              86                  3  20  1900
# 371         82             3              84                  4  20   510
# 372         80             1              81                  3  20   890
#
# 0     V-3    V-4  V-5      V-6  ...    V-22     V-23  V-24   V-25    V-26  \
# ...

# %%
data.columns
# Out:
# Index(['START YEAR', 'START QUARTER', 'COMPLETION YEAR', 'COMPLETION QUARTER',
#        'V-1', 'V-2', 'V-3', 'V-4', 'V-5', 'V-6',
#        ...
#        'V-22', 'V-23', 'V-24', 'V-25', 'V-26', 'V-27', 'V-28', 'V-29', 'V-9',
#        'V-10'],
#       dtype='object', name=0, length=109)

# %%
#checking if NaN values exist

print(data.isnull().sum())
# Out:
# 0
# START YEAR            0
# START QUARTER         0
# COMPLETION YEAR       0
# COMPLETION QUARTER    0
# V-1                   0
#                      ..
# V-27                  0
# V-28                  0
# V-29                  0
# V-9                   0
# V-10                  0
# Length: 109, dtype: int64

# %%
# checking if empty values exist

print(data.eq(" ").sum())
# Out:
# 0
# START YEAR            0
# START QUARTER         0
# COMPLETION YEAR       0
# COMPLETION QUARTER    0
# V-1                   0
#                      ..
# V-27                  0
# V-28                  0
# V-29                  0
# V-9                   0
# V-10                  0
# Length: 109, dtype: int64

# %% [markdown]
# NO NULL VALUES OR EMPTY CELLS

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 1 to 372
# Columns: 109 entries, START YEAR to V-10
# dtypes: object(109)
# memory usage: 316.9+ KB

# %%
data.nunique()
# Out:
# 0
# START YEAR             17
# START QUARTER           4
# COMPLETION YEAR        18
# COMPLETION QUARTER      4
# V-1                    20
#                      ...
# V-27                   67
# V-28                   67
# V-29                   67
# V-9                   117
# V-10                   62
# Length: 109, dtype: int64

# %% [markdown]
# From data info we can notice that all columns are of object type hence we need to change them to float

# %%
#changing the datatype from object to float for all columns

size = len(list(data.columns))
columns = list(data.columns)
for i in range(size):
     data[columns[i]]=data[columns[i]].astype(float)
# Out:
# <ipython-input-230-a2720747fd6a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[columns[i]]=data[columns[i]].astype(float)

# %%
# columns datatype changed to float

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 1 to 372
# Columns: 109 entries, START YEAR to V-10
# dtypes: float64(109)
# memory usage: 316.9 KB

# %%
data['V-11']
# Out:
# 0       V-11    V-11    V-11    V-11    V-11
# 1    6713.00  4986.0  6788.0  5728.0  7196.0
# 2    3152.00  2700.0  3561.0  3157.0  3678.0
# 3    1627.00  1580.0  2628.0  2374.0  2693.0
# 4    2580.93  2952.0  2649.0  2312.0  1381.0
# 5    6790.00  6370.0  5909.0  7045.0  5606.0
# ..       ...     ...     ...     ...     ...
# 368  2700.00  3561.0  3157.0  3678.0  2734.0
# 369  6713.00  6713.0  4986.0  6788.0  5728.0
# 370  2918.00  2264.0  2859.0  3152.0  2700.0
# 371  2247.00  2217.0  3255.0  3713.0  6796.0
# 372  7196.00  5275.0  4691.0  4072.0  3670.0
#
# [372 rows x 5 columns]

# %% [markdown]
# Data columns have duplicate names hence renaming them

# %%
data.columns = ['START YEAR','START QUARTER','COMPLETION YEAR','COMPLETION QUARTER',
 'V-1','V-2','V-3','V-4','V-5','V-6','V-7','V-8',
 'V-11','V-12','V-13','V-14','V-15','V-16','V-17','V-18','V-19','V-20','V-21','V-22','V-23','V-24','V-25','V-26','V-27','V-28','V-29',
 'V-30','V-31','V-32','V-33','V-34','V-35','V-36','V-37','V-38','V-39','V-40','V-41','V-42','V-43','V-44','V-45','V-46','V-47','V-48',
 'V-49','V-50','V-51','V-52','V-53','V-54','V-55','V-56','V-57','V-58','V-59','V-60','V-61','V-62','V-63','V-64','V-65','V-66','V-67',
 'V-68','V-69','V-70','V-71','V-72','V-73','V-74','V-75','V-76','V-77','V-78','V-79','V-80','V-81','V-82','V-83','V-84','V-85','V-86',             
 'V-87','V-88','V-89','V-90','V-91','V-92','V-93','V-94','V-95','V-96','V-97','V-98','V-99','V-100','V-101','V-102','V-103','V-104','V-105',                     
 'V-9','V-10']

# %%
#Dataset columns renamed, all having unique names

data.columns
# Out:
# Index(['START YEAR', 'START QUARTER', 'COMPLETION YEAR', 'COMPLETION QUARTER',
#        'V-1', 'V-2', 'V-3', 'V-4', 'V-5', 'V-6',
#        ...
#        'V-98', 'V-99', 'V-100', 'V-101', 'V-102', 'V-103', 'V-104', 'V-105',
#        'V-9', 'V-10'],
#       dtype='object', length=109)

# %%
#Corelation matrix for showing relationship between prdictors and target variables

corealtion_matrix = data.corr()
corealtion_matrix
# Out:
#                     START YEAR  START QUARTER  COMPLETION YEAR  \
# START YEAR            1.000000      -0.122166         0.988406
# START QUARTER        -0.122166       1.000000        -0.057468
# COMPLETION YEAR       0.988406      -0.057468         1.000000
# COMPLETION QUARTER    0.053076      -0.198444        -0.020705
# V-1                   0.135501       0.034600         0.136519
# ...                        ...            ...              ...
# V-103                 0.870671      -0.007638         0.868584
# V-104                 0.319821      -0.360814         0.307949
# V-105                 0.902521      -0.074340         0.887820
# V-9                   0.607124      -0.093030         0.612665
# V-10                  0.753455      -0.128630         0.768546
#
#                     COMPLETION QUARTER       V-1       V-2       V-3  \
# START YEAR                    0.053076  0.135501  0.089259  0.066719
# ...

# %%
corealtion_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from numpy import mean
from numpy import absolute
import xgboost
from xgboost import XGBRegressor
from sklearn.preprocessing import PolynomialFeatures

# %%
x = data[['START YEAR','START QUARTER','COMPLETION YEAR','COMPLETION QUARTER',
 'V-1','V-2','V-3','V-4','V-5','V-6','V-7','V-8',
 'V-11','V-12','V-13','V-14','V-15','V-16','V-17','V-18','V-19','V-20','V-21','V-22','V-23','V-24','V-25','V-26','V-27','V-28','V-29',
 'V-30','V-31','V-32','V-33','V-34','V-35','V-36','V-37','V-38','V-39','V-40','V-41','V-42','V-43','V-44','V-45','V-46','V-47','V-48',
 'V-49','V-50','V-51','V-52','V-53','V-54','V-55','V-56','V-57','V-58','V-59','V-60','V-61','V-62','V-63','V-64','V-65','V-66','V-67',
 'V-68','V-69','V-70','V-71','V-72','V-73','V-74','V-75','V-76','V-77','V-78','V-79','V-80','V-81','V-82','V-83','V-84','V-85','V-86',             
 'V-87','V-88','V-89','V-90','V-91','V-92','V-93','V-94','V-95','V-96','V-97','V-98','V-99','V-100','V-101','V-102','V-103','V-104','V-105',                     
 ]]
y = data['V-9']

# %% [markdown]
# # (i) - Model Performance with all features selected

# %%
# setting x and y values for training and testing the model

df = data.copy()
train_cols = df.columns[0:-2]
target = data.columns[-2]

x = df[train_cols]
y = df[target]

# %%
model = XGBRegressor()
kfold = KFold(n_splits=10)
score_mae = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',cv=kfold, n_jobs=-1)
score_rmse = cross_val_score(model, x, y, scoring='neg_root_mean_squared_error',cv=kfold, n_jobs=-1)

score_mae = absolute(score_mae)
score_rmse = absolute(score_rmse)
print('Mean MAE: %.3f' % score_mae.mean())
print('Mean RMSE: %.3f' % score_rmse.mean())
# Out:
# Mean MAE: 117.900
# Mean RMSE: 197.928

# %% [markdown]
# # (ii) - Model Performance with 7 features selected

# %%
from sklearn.feature_selection import SelectKBest
from sklearn import feature_selection
from sklearn.feature_selection import f_regression
from numpy import array

# %% [markdown]
# ###### Using SelectKbest method

# %%
df = data.copy()
train_cols = df.columns[0:-2]
target = data.columns[-2]

x = df[train_cols]
y = df[target]

# %%
select_features = SelectKBest(score_func=f_regression, k=7)
z = select_features.fit_transform(x, y) 
z.shape
features = array(df.columns)
features = features[features!='V-9']
features = features[features!='V-10']

filter = select_features.get_support()

print("All features:")
print(features)
 
print("\n\n Selected best 7:")
print(features[filter])
# Out:
# All features:
# ['START YEAR' 'START QUARTER' 'COMPLETION YEAR' 'COMPLETION QUARTER' 'V-1'
#  'V-2' 'V-3' 'V-4' 'V-5' 'V-6' 'V-7' 'V-8' 'V-11' 'V-12' 'V-13' 'V-14'
#  'V-15' 'V-16' 'V-17' 'V-18' 'V-19' 'V-20' 'V-21' 'V-22' 'V-23' 'V-24'
#  'V-25' 'V-26' 'V-27' 'V-28' 'V-29' 'V-30' 'V-31' 'V-32' 'V-33' 'V-34'
#  'V-35' 'V-36' 'V-37' 'V-38' 'V-39' 'V-40' 'V-41' 'V-42' 'V-43' 'V-44'
#  'V-45' 'V-46' 'V-47' 'V-48' 'V-49' 'V-50' 'V-51' 'V-52' 'V-53' 'V-54'
#  'V-55' 'V-56' 'V-57' 'V-58' 'V-59' 'V-60' 'V-61' 'V-62' 'V-63' 'V-64'
#  'V-65' 'V-66' 'V-67' 'V-68' 'V-69' 'V-70' 'V-71' 'V-72' 'V-73' 'V-74'
#  'V-75' 'V-76' 'V-77' 'V-78' 'V-79' 'V-80' 'V-81' 'V-82' 'V-83' 'V-84'
#  'V-85' 'V-86' 'V-87' 'V-88' 'V-89' 'V-90' 'V-91' 'V-92' 'V-93' 'V-94'
#  'V-95' 'V-96' 'V-97' 'V-98' 'V-99' 'V-100' 'V-101' 'V-102' 'V-103'
#  'V-104' 'V-105']
#
#
#  Selected best 7:
# ['COMPLETION YEAR' 'V-5' 'V-8' 'V-82' 'V-83' 'V-101' 'V-102']

# %%
Y = data['V-9']
X = data[['COMPLETION YEAR', 'V-5', 'V-8', 'V-82', 'V-83', 'V-101', 'V-102']]

pf=PolynomialFeatures(degree=2)     #Linear Equation of degree 2
X_poly=pf.fit_transform(X) 
X_poly

model = XGBRegressor()
kfold = KFold(n_splits=10)
score_mae = cross_val_score(model, X_poly, Y, scoring='neg_mean_absolute_error',cv=kfold, n_jobs=-1)
score_rmse = cross_val_score(model, X_poly, Y, scoring='neg_root_mean_squared_error',cv=kfold, n_jobs=-1)

score_mae = absolute(score_mae)
score_rmse = absolute(score_rmse)
print('Mean MAE: %.3f' % score_mae.mean())
print('Mean RMSE: %.3f' % score_rmse.mean())
# Out:
# Mean MAE: 133.316
# Mean RMSE: 198.351

# %% [markdown]
# ###### Using recurssive feature elemination method

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline

df = data.copy()
train_cols = df.columns[0:-2]
target = data.columns[-2]

X = df[train_cols]
Y = df[target]

rfe = RFE(estimator=DecisionTreeRegressor(), n_features_to_select=7)
model = XGBRegressor()
pipeline = Pipeline(steps=[('s',rfe),('m',model)])
cv = kfold = KFold(n_splits=10)

score_mae = cross_val_score(pipeline, X, Y, scoring='neg_mean_absolute_error',cv=kfold, n_jobs=-1)
score_rmse = cross_val_score(pipeline, X, Y, scoring='neg_root_mean_squared_error',cv=kfold, n_jobs=-1)

score_mae = absolute(score_mae)
score_rmse = absolute(score_rmse)
print('Mean MAE: %.3f' % score_mae.mean())
print('Mean RMSE: %.3f' % score_rmse.mean())
# Out:
# Mean MAE: 116.457
# Mean RMSE: 198.417
